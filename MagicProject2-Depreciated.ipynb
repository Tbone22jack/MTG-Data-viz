# %%
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn import linear_model
from sklearn.cluster import KMeans
from mpl_toolkits import mplot3d
import re

# %%
set_info = pd.read_csv("C:/Users/thoma/Desktop/Magic Project/data/AllPrintingsCSVFiles/sets.csv",usecols= ['name','code','releaseDate'])
set_info.columns = ['setCode','setName','releaseDate']
card_info = pd.read_csv("C:/Users/thoma/Desktop/Magic Project/data/AllPrintingsCSVFiles/cards.csv",usecols=["name","setCode","edhrecRank","convertedManaCost","isReserved","originalReleaseDate","rarity","text","colors"])
card_info.columns = ["colors","convertedManaCost","edhrecRank","isReserved","name","originalReleaseDate","rarity","setCode","text"]
# Out:
# C:\Users\thoma\AppData\Local\Temp\ipykernel_7732\4278852833.py:3: DtypeWarning: Columns (51) have mixed types. Specify dtype option on import or set low_memory=False.
#   card_info = pd.read_csv("C:/Users/thoma/Desktop/Magic Project/data/AllPrintingsCSVFiles/cards.csv",usecols=["name","setCode","edhrecRank","convertedManaCost","isReserved","originalReleaseDate","rarity","text","colors"])

# %%
card_info
# Out:
#       colors  convertedManaCost  edhrecRank  isReserved                 name  \
# 0          W                7.0     15723.0           0    Ancestor's Chosen
# 1          W                5.0     12809.0           0       Angel of Mercy
# 2          W                4.0     11227.0           0     Aven Cloudchaser
# 3          W                4.0     12901.0           0       Ballista Squad
# 4          W                1.0      3975.0           0              Bandage
# ...      ...                ...         ...         ...                  ...
# 56776      U                2.0      1147.0           0        Into the Roil
# 56777      B                1.0      8902.0           0  Bloodchief's Thirst
# 56778      R                2.0     14041.0           0        Roil Eruption
# 56779      G                3.0      1888.0           0     Roiling Regrowth
# 56780    R,W                3.0     10517.0           0     Kargan Warleader
#
#       originalReleaseDate    rarity setCode  \
# 0                     NaN  uncommon     10E
# 1                     NaN  uncommon     10E
# 2                     NaN    common     10E
# 3                     NaN  uncommon     10E
# 4                     NaN    common     10E
# ...                   ...       ...     ...
# 56776                 NaN    common     ZNR
# 56777                 NaN  uncommon     ZNR
# 56778                 NaN    common     ZNR
# 56779                 NaN  uncommon     ZNR
# 56780                 NaN  uncommon     ZNR
#
#                                                     text
# 0      First strike (This creature deals combat damag...
# 1      Flying\nWhen Angel of Mercy enters the battlef...
# 2      Flying (This creature can't be blocked except ...
# 3      {X}{W}, {T}: Ballista Squad deals X damage to ...
# 4      Prevent the next 1 damage that would be dealt ...
# ...                                                  ...
# 56776  Kicker {1}{U} (You may pay an additional {1}{U...
# 56777  Kicker {2}{B} (You may pay an additional {2}{B...
# 56778  Kicker {5} (You may pay an additional {5} as y...
# 56779  Sacrifice a land. Search your library for up t...
# 56780              Other Warriors you control get +1/+1.
#
# [56781 rows x 9 columns]

# %%
set_info
# Out:
#     setCode                              setName releaseDate
# 0       10E                        Tenth Edition  2007-07-13
# 1       2ED                    Unlimited Edition  1993-12-01
# 2       2XM                       Double Masters  2020-08-07
# 3       3ED                      Revised Edition  1994-04-01
# 4       4BB  Fourth Edition Foreign Black Border  1995-04-01
# ..      ...                                  ...         ...
# 548     XLN                               Ixalan  2017-09-29
# 549     ZEN                             Zendikar  2009-10-02
# 550     ZNC            Zendikar Rising Commander  2020-09-25
# 551     ZNE          Zendikar Rising Expeditions  2020-09-25
# 552     ZNR                      Zendikar Rising  2020-09-25
#
# [553 rows x 3 columns]

# %%
set_info.loc[set_info['setCode'].isin(['UNH'])]
# Out:
#     setCode   setName releaseDate
# 520     UNH  Unhinged  2004-11-19

# %%
card_info.loc[card_info['setCode'].isin(['UNH'])].sort_values(by = 'convertedManaCost')
# Out:
#        convertedManaCost  edhrecRank  isReserved  \
# 52680                0.0         NaN           0
# 52559                0.0         NaN           0
# 52683                0.0         NaN           0
# 52682                0.0         NaN           0
# 52681                0.0         NaN           0
# ...                  ...         ...         ...
# 52664               13.0         NaN           0
# 52625               15.0         NaN           0
# 52624               15.0         NaN           0
# 52587          1000000.0         NaN           0
# 52526          1000000.0         NaN           0
#
#                                       name originalReleaseDate  rarity  \
# 52680                               Island                 NaN  common
# 52559                          City of Ass                 NaN    rare
# 52683                               Forest                 NaN  common
# 52682                             Mountain                 NaN  common
# 52681                                Swamp                 NaN  common
# ...                                    ...                 ...     ...
# 52664  Who // What // When // Where // Why                 NaN    rare
# 52625                            Mox Lotus                 NaN    rare
# 52624                            Mox Lotus                 NaN    rare
# 52587                              Gleemax                 NaN    rare
# 52526                              Gleemax                 NaN    rare
#
#       setCode                                               text
# 52680     UNH                                    ({T}: Add {U}.)
# 52559     UNH  City of Ass enters the battlefield tapped.\n{T...
# 52683     UNH                                    ({T}: Add {G}.)
# 52682     UNH                                    ({T}: Add {R}.)
# 52681     UNH                                    ({T}: Add {B}.)
# ...       ...                                                ...
# 52664     UNH                        Target player gains X life.
# 52625     UNH   {T}: Add {∞}.\n{100}: Add one mana of any color.
# 52624     UNH   {T}: Add {∞}.\n{100}: Add one mana of any color.
# 52587     UNH  You choose all targets for all spells and abil...
# 52526     UNH  You choose all targets for all spells and abil...
#
# [173 rows x 8 columns]

# %%
card_info['edhrecRank'].max()
# Out:
# 20898.0

# %%
values = {"convertedManaCost":0.0  ,"edhrecRank" : 20899.0, "isReserved" : 0, "name": 'loool', "originalReleaseDate": 7, "rarity": 'common',"setCode": 'Please Label set','text':'please enter text'}
card_info.fillna(value = values,inplace = True)

# %%
card_info.groupby(['setCode']).get_group('10E')['edhrecRank'].nsmallest(5).values
# Out:
# array([12., 23., 29., 47., 58.])

# %%
data_m = pd.DataFrame()

# %%
data_m
# Out:
#        B    B,G   B,G,R  B,G,R,U,W   B,G,U   B,G,W    B,R   B,R,U   B,R,W  \
# 0   31.0  155.0  1454.0     2137.0   699.0  1370.0  259.0  1196.0  1022.0
# 1   31.0  155.0  1454.0     2137.0   699.0  1370.0  259.0  1196.0  1022.0
# 2   31.0  155.0  1603.0     2137.0   699.0  1370.0  259.0  1196.0  1022.0
# 3   31.0  155.0  1603.0     2137.0   699.0  1370.0  259.0  1673.0  1022.0
# 4   31.0  203.0  1603.0     2317.0   859.0  1816.0  259.0  1673.0  1022.0
# 5   31.0  203.0  2731.0     2317.0   859.0  1816.0  259.0  1673.0  1214.0
# 6   31.0  203.0  2731.0     2317.0   859.0  1816.0  259.0  1673.0  1214.0
# 7   31.0  203.0  2731.0     2576.0   859.0  1816.0  259.0  1673.0  1214.0
# 8   31.0  203.0  2731.0     2748.0  1317.0  2220.0  259.0  1673.0  1214.0
# 9   31.0  203.0  2923.0     2748.0  1317.0  2220.0  259.0  1673.0  1755.0
# 10  31.0  203.0  2923.0     2761.0  1317.0  2220.0  259.0  1673.0  1755.0
# 11  31.0  203.0  3277.0     2761.0  1473.0  2220.0  259.0  1673.0  1755.0
# 12  31.0  203.0  3277.0     2788.0  1473.0  2220.0  259.0  1732.0  1755.0
# 13  31.0  203.0  3739.0     2788.0  1473.0  2417.0  259.0  1732.0  2344.0
# 14  31.0  203.0  3739.0     2879.0  1473.0  2417.0  259.0  1732.0  2344.0
# 15  31.0  203.0  3739.0     2879.0  1473.0  2417.0  259.0  1732.0  2344.0
# 16  31.0  203.0  4297.0     2879.0  2340.0  2417.0  259.0  1923.0  2814.0
# 17  31.0  203.0  4297.0     3074.0  2340.0  2471.0  259.0  1923.0  2814.0
# 18  31.0  203.0  4352.0     3074.0  2904.0  2471.0  259.0  1923.0  2814.0
# 19  31.0  203.0  4352.0     3074.0  2904.0  2471.0  456.0  1923.0  2814.0
#
#       B,U  ...    G,U   G,U,W    G,W     R    R,U   R,U,W    R,W     U    U,W  \
# 0   377.0  ...  247.0  1566.0  225.0  43.0  514.0  1549.0  180.0  17.0  153.0
# 1   377.0  ...  247.0  1566.0  225.0  43.0  514.0  1549.0  180.0  17.0  153.0
# 2   377.0  ...  247.0  1566.0  225.0  43.0  514.0  1549.0  180.0  17.0  240.0
# 3   392.0  ...  247.0  1754.0  298.0  43.0  636.0  1684.0  180.0  17.0  240.0
# 4   392.0  ...  250.0  1754.0  298.0  43.0  636.0  1684.0  180.0  17.0  240.0
# 5   392.0  ...  250.0  2003.0  298.0  43.0  636.0  1725.0  180.0  17.0  240.0
# 6   392.0  ...  250.0  2003.0  298.0  43.0  636.0  1725.0  180.0  17.0  240.0
# 7   392.0  ...  352.0  2115.0  298.0  43.0  636.0  2042.0  180.0  17.0  459.0
# 8   392.0  ...  352.0  2115.0  298.0  43.0  636.0  2529.0  657.0  17.0  459.0
# 9   392.0  ...  352.0  2115.0  298.0  43.0  644.0  2529.0  657.0  17.0  459.0
# 10  392.0  ...  352.0  2115.0  298.0  43.0  644.0  2529.0  657.0  17.0  459.0
# 11  392.0  ...  352.0  2276.0  298.0  43.0  644.0  2529.0  657.0  17.0  459.0
# 12  392.0  ...  352.0  2276.0  298.0  64.0  644.0  2720.0  657.0  17.0  717.0
# 13  400.0  ...  352.0  2496.0  457.0  64.0  644.0  2747.0  657.0  17.0  717.0
# 14  400.0  ...  352.0  2496.0  457.0  64.0  663.0  2747.0  787.0  17.0  717.0
# 15  400.0  ...  352.0  2768.0  457.0  64.0  663.0  2747.0  787.0  17.0  717.0
# 16  400.0  ...  352.0  2768.0  457.0  64.0  663.0  4017.0  787.0  17.0  717.0
# 17  400.0  ...  352.0  2768.0  581.0  64.0  663.0  4017.0  872.0  17.0  717.0
# 18  400.0  ...  352.0  3003.0  581.0  64.0  663.0  4017.0  872.0  17.0  717.0
# 19  480.0  ...  352.0  3003.0  581.0  64.0  663.0  4017.0  872.0  17.0  993.0
#
#        W
# 0   14.0
# 1   14.0
# 2   14.0
# 3   14.0
# 4   14.0
# 5   14.0
# 6   14.0
# 7   14.0
# 8   14.0
# 9   14.0
# 10  14.0
# 11  14.0
# 12  14.0
# 13  14.0
# 14  14.0
# 15  14.0
# 16  14.0
# 17  14.0
# 18  14.0
# 19  14.0
#
# [20 rows x 26 columns]

# %%
data_m = pd.DataFrame()
n_small = 20
for group in card_info.groupby(['colors']).groups:
    if card_info.groupby(['colors']).get_group(group)['edhrecRank'].nsmallest(n_small).size >= n_small:
        data_m[group] = card_info.groupby(['colors']).get_group(group)['edhrecRank'].nsmallest(n_small).values
        print(data_m)

# %% [markdown]
# This merges the set and card info into one dataframe. They are merged on the set code.

# %%
expanded_info = pd.merge(set_info,card_info.groupby(['setCode']).mean(), left_on = 'setCode', right_on = 'setCode')

# %% [markdown]
# This removes the basic lands in the set as they have a cmc of 0 and are run in alot of decks. This could bias the data so it must be removed.

# %%
basics_removed = card_info.drop(card_info.loc[card_info['name'].isin(['Island','Mountain','Swamp','Plains','Forest'])].index)

# %%
basics_removed
# Out:
#       colors  convertedManaCost  edhrecRank  isReserved                 name  \
# 0          W                7.0     15723.0           0    Ancestor's Chosen
# 1          W                5.0     12809.0           0       Angel of Mercy
# 2          W                4.0     11227.0           0     Aven Cloudchaser
# 3          W                4.0     12901.0           0       Ballista Squad
# 4          W                1.0      3975.0           0              Bandage
# ...      ...                ...         ...         ...                  ...
# 56776      U                2.0      1147.0           0        Into the Roil
# 56777      B                1.0      8902.0           0  Bloodchief's Thirst
# 56778      R                2.0     14041.0           0        Roil Eruption
# 56779      G                3.0      1888.0           0     Roiling Regrowth
# 56780    R,W                3.0     10517.0           0     Kargan Warleader
#
#       originalReleaseDate    rarity setCode  \
# 0                     NaN  uncommon     10E
# 1                     NaN  uncommon     10E
# 2                     NaN    common     10E
# 3                     NaN  uncommon     10E
# 4                     NaN    common     10E
# ...                   ...       ...     ...
# 56776                 NaN    common     ZNR
# 56777                 NaN  uncommon     ZNR
# 56778                 NaN    common     ZNR
# 56779                 NaN  uncommon     ZNR
# 56780                 NaN  uncommon     ZNR
#
#                                                     text
# 0      First strike (This creature deals combat damag...
# 1      Flying\nWhen Angel of Mercy enters the battlef...
# 2      Flying (This creature can't be blocked except ...
# 3      {X}{W}, {T}: Ballista Squad deals X damage to ...
# 4      Prevent the next 1 damage that would be dealt ...
# ...                                                  ...
# 56776  Kicker {1}{U} (You may pay an additional {1}{U...
# 56777  Kicker {2}{B} (You may pay an additional {2}{B...
# 56778  Kicker {5} (You may pay an additional {5} as y...
# 56779  Sacrifice a land. Search your library for up t...
# 56780              Other Warriors you control get +1/+1.
#
# [53518 rows x 9 columns]

# %% [markdown]
# We need to remove all the extraneous small batches of cards. Although there are releases like commander collections because they dont present new cards.

# %%
full_sets = basics_removed.groupby('setCode').filter(lambda x: len(x) > 100)

# %%
full_sets
# Out:
#       colors  convertedManaCost  edhrecRank  isReserved                 name  \
# 0          W                7.0     15723.0           0    Ancestor's Chosen
# 1          W                5.0     12809.0           0       Angel of Mercy
# 2          W                4.0     11227.0           0     Aven Cloudchaser
# 3          W                4.0     12901.0           0       Ballista Squad
# 4          W                1.0      3975.0           0              Bandage
# ...      ...                ...         ...         ...                  ...
# 56776      U                2.0      1147.0           0        Into the Roil
# 56777      B                1.0      8902.0           0  Bloodchief's Thirst
# 56778      R                2.0     14041.0           0        Roil Eruption
# 56779      G                3.0      1888.0           0     Roiling Regrowth
# 56780    R,W                3.0     10517.0           0     Kargan Warleader
#
#       originalReleaseDate    rarity setCode  \
# 0                     NaN  uncommon     10E
# 1                     NaN  uncommon     10E
# 2                     NaN    common     10E
# 3                     NaN  uncommon     10E
# 4                     NaN    common     10E
# ...                   ...       ...     ...
# 56776                 NaN    common     ZNR
# 56777                 NaN  uncommon     ZNR
# 56778                 NaN    common     ZNR
# 56779                 NaN  uncommon     ZNR
# 56780                 NaN  uncommon     ZNR
#
#                                                     text
# 0      First strike (This creature deals combat damag...
# 1      Flying\nWhen Angel of Mercy enters the battlef...
# 2      Flying (This creature can't be blocked except ...
# 3      {X}{W}, {T}: Ballista Squad deals X damage to ...
# 4      Prevent the next 1 damage that would be dealt ...
# ...                                                  ...
# 56776  Kicker {1}{U} (You may pay an additional {1}{U...
# 56777  Kicker {2}{B} (You may pay an additional {2}{B...
# 56778  Kicker {5} (You may pay an additional {5} as y...
# 56779  Sacrifice a land. Search your library for up t...
# 56780              Other Warriors you control get +1/+1.
#
# [46513 rows x 9 columns]

# %%
full_sets.merge(set_info, left_on = 'setCode', right_on = 'setCode').sort_values('releaseDate').loc[full_sets.merge(set_info, left_on = 'setCode', right_on = 'setCode').sort_values('releaseDate')['name'].isin(['Toski, Bearer of Secrets'])]
# Out:
#       colors  convertedManaCost  edhrecRank  isReserved  \
# 20873      G                4.0      7104.0           0
# 32891      G                4.0      7104.0           0
# 21016      G                4.0      7104.0           0
# 32892      G                4.0      7104.0           0
#
#                            name originalReleaseDate rarity setCode  \
# 20873  Toski, Bearer of Secrets                 NaN   rare     KHM
# 32891  Toski, Bearer of Secrets                 NaN   rare    PKHM
# 21016  Toski, Bearer of Secrets                 NaN   rare     KHM
# 32892  Toski, Bearer of Secrets                 NaN   rare    PKHM
#
#                                                     text          setName  \
# 20873  This spell can't be countered.\nIndestructible...         Kaldheim
# 32891  This spell can't be countered.\nIndestructible...  Kaldheim Promos
# 21016  This spell can't be countered.\nIndestructible...         Kaldheim
# 32892  This spell can't be countered.\nIndestructible...  Kaldheim Promos
#
#       releaseDate
# 20873  2021-02-05
# 32891  2021-02-05
# 21016  2021-02-05
# 32892  2021-02-05

# %% [markdown]
# Drops dupes so we can only see the first printing of any card.

# %%
dupes_dropped = full_sets.merge(set_info, left_on = 'setCode', right_on = 'setCode').sort_values('releaseDate').drop_duplicates(subset=['name'], keep = 'first')

# %%
dupes_dropped
# Out:
#       colors  convertedManaCost  edhrecRank  isReserved  \
# 21907      W                2.0     11661.0           0
# 21967      U                2.0     19535.0           0
# 21968      U                1.0      5173.0           0
# 21969      U                3.0      7373.0           0
# 21970      U                3.0     12292.0           0
# ...      ...                ...         ...         ...
# 21074      R                5.0     13299.0           0
# 21073      B                5.0     15299.0           0
# 21072      U                7.0     13568.0           0
# 21071      W                6.0     11594.0           0
# 21086      R                2.0     14333.0           0
#
#                               name originalReleaseDate    rarity setCode  \
# 21907  Circle of Protection: Green                 NaN    common     LEA
# 21967                   Power Leak                 NaN    common     LEA
# 21968                   Power Sink                 NaN    common     LEA
# 21969            Prodigal Sorcerer                 NaN    common     LEA
# 21970                Psionic Blast                 NaN  uncommon     LEA
# ...                            ...                 ...       ...     ...
# 21074             Surtland Flinger                 NaN      rare     KHM
# 21073              Cleaving Reaper                 NaN      rare     KHM
# 21072        Surtland Elementalist                 NaN      rare     KHM
# 21071           Valkyrie Harbinger                 NaN      rare     KHM
# 21086            Fire Giant's Fury                 NaN  uncommon     KHM
#
#                                                     text  \
# 21907  {1}: The next time a green source of your choi...
# 21967  Enchant enchantment\nAt the beginning of the u...
# 21968  Counter target spell unless its controller pay...
# 21969  {T}: Prodigal Sorcerer deals 1 damage to any t...
# 21970  Psionic Blast deals 4 damage to any target and...
# ...                                                  ...
# 21074  Whenever Surtland Flinger attacks, you may sac...
# 21073  Flying, trample\nPay 3 life: Return Cleaving R...
# 21072  As an additional cost to cast this spell, reve...
# 21071  Flying, lifelink\nAt the beginning of each end...
# 21086  Target Giant you control gets +2/+2 and gains ...
#
#                      setName releaseDate
# 21907  Limited Edition Alpha  1993-08-05
# 21967  Limited Edition Alpha  1993-08-05
# 21968  Limited Edition Alpha  1993-08-05
# 21969  Limited Edition Alpha  1993-08-05
# 21970  Limited Edition Alpha  1993-08-05
# ...                      ...         ...
# 21074               Kaldheim  2021-02-05
# 21073               Kaldheim  2021-02-05
# 21072               Kaldheim  2021-02-05
# 21071               Kaldheim  2021-02-05
# 21086               Kaldheim  2021-02-05
#
# [21252 rows x 11 columns]

# %%
dupes_dropped[dupes_dropped['edhrecRank'] < 2500].sort_values('edhrecRank')
# Out:
#       colors  convertedManaCost  edhrecRank  isReserved  \
# 22165    NaN                1.0         1.0           0
# 34941    NaN                0.0         2.0           0
# 34890    NaN                0.0         8.0           0
# 14948    NaN                2.0         9.0           0
# 35381    NaN                0.0        10.0           0
# ...      ...                ...         ...         ...
# 34663      U                2.0      2495.0           0
# 5989   G,U,W                3.0      2496.0           0
# 13704      R                6.0      2497.0           0
# 42956    NaN                3.0      2498.0           1
# 39941      B                2.0      2499.0           0
#
#                           name originalReleaseDate    rarity setCode  \
# 22165                 Sol Ring                 NaN  uncommon     LEA
# 34941            Command Tower          2013-04-09    common     PRM
# 34890           Evolving Wilds          2013-01-11    common     PRM
# 14948            Arcane Signet                 NaN    common     ELD
# 35381          Reliquary Tower          2018-07-14  uncommon     PRM
# ...                        ...                 ...       ...     ...
# 34663               Willbender          2014-10-17  uncommon     PRM
# 5989                   Wargate                 NaN      rare     ARB
# 13704  Flayer of the Hatebound                 NaN      rare     DKA
# 42956              Metalworker                 NaN      rare     UDS
# 39941          Relentless Dead                 NaN    mythic     SOI
#
#                                                     text  \
# 22165                                   {T}: Add {C}{C}.
# 34941  {T}: Add one mana of any color in your command...
# 34890  {T}, Sacrifice Evolving Wilds: Search your lib...
# 14948  {T}: Add one mana of any color in your command...
# 35381      You have no maximum hand size.\n{T}: Add {C}.
# ...                                                  ...
# 34663  Morph {1}{U} (You may cast this card face down...
# 5989   Search your library for a permanent card with ...
# 13704  Undying (When this creature dies, if it had no...
# 42956  {T}: Reveal any number of artifact cards in yo...
# 39941  Menace (This creature can't be blocked except ...
#
#                       setName releaseDate
# 22165   Limited Edition Alpha  1993-08-05
# 34941     Magic Online Promos  2002-06-24
# 34890     Magic Online Promos  2002-06-24
# 14948      Throne of Eldraine  2019-10-04
# 35381     Magic Online Promos  2002-06-24
# ...                       ...         ...
# 34663     Magic Online Promos  2002-06-24
# 5989             Alara Reborn  2009-04-30
# 13704          Dark Ascension  2012-02-03
# 42956          Urza's Destiny  1999-06-07
# 39941  Shadows over Innistrad  2016-04-08
#
# [2482 rows x 11 columns]
